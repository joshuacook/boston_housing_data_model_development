# %%
cd ..
# Out:
# /home/jovyan/portfolio/ames_housing_data_model_development

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.tree import DecisionTreeRegressor
import lib.eda as eda
# %matplotlib inline

# %% [markdown]
# # Create Categorical Features

# %%
ames_train_df = pd.read_pickle('data/train_df.p')
ames_test_df = pd.read_pickle('data/test_df.p')

# %%
ames_train_df.shape, ames_test_df.shape
# Out:
# ((1459, 82), (1459, 81))

# %%
ames_train_df.sample(5)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 731        120       RL         39.0     5389   Pave  None      IR1
# 84          20       RL         80.0     8892   Pave  None      IR1
# 305         75       RM         87.0    18386   Pave  None      Reg
# 227         60       RL         82.0     9950   Pave  None      IR1
# 677         70       RM         60.0     9600   Pave  Grvl      Reg
#
#     LandContour Utilities LotConfig      ...      MiscVal MoSold YrSold  \
# Id                                       ...
# 731         Lvl    AllPub    Inside      ...            0      3   2010
# 84          Lvl    AllPub    Inside      ...            0      7   2007
# 305         Lvl    AllPub    Inside      ...            0      5   2008
# 227         Lvl    AllPub    Inside      ...            0      6   2007
# 677         Lvl    AllPub    Inside      ...            0      5   2006
#
#     SaleType SaleCondition SalePrice  MasVnrType_1  MasVnrType_2  \
# Id
# 731       WD        Normal    236500          None          None
# 84       COD        Normal    126500        BrkCmn        BrkCmn
# 305       WD        Normal    295000          None          None
# 227       WD       Abnorml    290000       BrkFace       BrkFace
# 677       WD        Normal     87000          None          None
#
#      MasVnrArea_1  MasVnrArea_2
# Id
# 731           0.0           0.0
# 84           66.0          66.0
# 305           0.0           0.0
# 227         290.0         290.0
# 677           0.0           0.0
#
# [5 rows x 82 columns]

# %% [markdown]
# ### Which features are numerical and categorical?

# %%
for i, col in enumerate(ames_train_df.columns):
    dtype = ames_train_df[col].dtype    
    unique_train = ames_train_df[col].unique()
    unique_test = ames_train_df[col].unique()
    diff_test_train = set(unique_test) - set(unique_train)
    if len(unique_train) > 20:
        unique_train = "list length: {}".format(len(unique_train))
    print("{:3} {:20} {:10} \n{}".format(str(i), col, str(dtype), str(unique_train), str(diff_test_train)))
    if len(diff_test_train) > 0:
        print("diff: ".format(str(diff_test_train)))
    print()
# Out:
# 0   MSSubClass           object
# [60 20 70 50 190 45 90 120 30 85 80 160 75 180 40]
#
# 1   MSZoning             object
# ['RL' 'RM' 'C (all)' 'FV' 'RH']
#
# 2   LotFrontage          float64
# list length: 111
#
# 3   LotArea              int64
# list length: 1072
#
# 4   Street               object
# ['Pave' 'Grvl']
#
# 5   Alley                object
# ['None' 'Grvl' 'Pave']
#
# 6   LotShape             object
# ['Reg' 'IR1' 'IR2' 'IR3']
#
# 7   LandContour          object
# ['Lvl' 'Bnk' 'Low' 'HLS']
#
# 8   Utilities            object
# ['AllPub' 'NoSeWa']
#
# 9   LotConfig            object
# ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
#
# 10  LandSlope            object
# ['Gtl' 'Mod' 'Sev']
#
# 11  Neighborhood         object
# list length: 25
#
# 12  Condition1           object
# ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
#
# 13  Condition2           object
# ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe']
#
# 14  BldgType             object
# ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
#
# 15  HouseStyle           object
# ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
#
# 16  OverallQual          int64
# [ 7  6  8  5  9  4 10  3  1  2]
#
# 17  OverallCond          int64
# [5 8 6 7 4 2 3 9 1]
#
# 18  YearBuilt            int64
# list length: 112
#
# 19  YearRemodAdd         int64
# list length: 61
#
# 20  RoofStyle            object
# ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed']
#
# 21  RoofMatl             object
# ['CompShg' 'WdShngl' 'Metal' 'WdShake' 'Membran' 'Tar&Grv' 'Roll' 'ClyTile']
#
# 22  Exterior1st          object
# ['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace' 'WdShing' 'CemntBd'
#  'Plywood' 'AsbShng' 'Stucco' 'BrkComm' 'AsphShn' 'Stone' 'ImStucc'
#  'CBlock']
#
# 23  Exterior2nd          object
# ['VinylSd' 'MetalSd' 'Wd Shng' 'HdBoard' 'Plywood' 'Wd Sdng' 'CmentBd'
#  'BrkFace' 'Stucco' 'AsbShng' 'Brk Cmn' 'ImStucc' 'AsphShn' 'Stone' 'Other'
#  'CBlock']
#
# 24  ExterQual            object
# ['Gd' 'TA' 'Ex' 'Fa']
#
# 25  ExterCond            object
# ['TA' 'Gd' 'Fa' 'Po' 'Ex']
#
# 26  Foundation           object
# ['PConc' 'CBlock' 'BrkTil' 'Wood' 'Slab' 'Stone']
#
# 27  BsmtQual             object
# ['Gd' 'TA' 'Ex' 'None' 'Fa']
#
# 28  BsmtCond             object
# ['TA' 'Gd' 'None' 'Fa' 'Po']
#
# 29  BsmtExposure         object
# ['No' 'Gd' 'Mn' 'Av' 'None']
#
# 30  BsmtFinType1         object
# ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' 'None' 'LwQ']
#
# 31  BsmtFinSF1           int64
# list length: 637
#
# 32  BsmtFinType2         object
# ['Unf' 'BLQ' 'None' 'ALQ' 'Rec' 'LwQ' 'GLQ']
#
# 33  BsmtFinSF2           int64
# list length: 144
#
# 34  BsmtUnfSF            int64
# list length: 780
#
# 35  TotalBsmtSF          int64
# list length: 721
#
# 36  Heating              object
# ['GasA' 'GasW' 'Grav' 'Wall' 'OthW' 'Floor']
#
# 37  HeatingQC            object
# ['Ex' 'Gd' 'TA' 'Fa' 'Po']
#
# 38  CentralAir           object
# ['Y' 'N']
#
# 39  Electrical           object
# ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix']
#
# 40  1stFlrSF             int64
# list length: 752
#
# 41  2ndFlrSF             int64
# list length: 417
#
# 42  LowQualFinSF         int64
# list length: 24
#
# 43  GrLivArea            int64
# list length: 861
#
# 44  BsmtFullBath         int64
# [1 0 2 3]
#
# 45  BsmtHalfBath         int64
# [0 1 2]
#
# 46  FullBath             int64
# [2 1 3 0]
#
# 47  HalfBath             int64
# [1 0 2]
#
# 48  BedroomAbvGr         int64
# [3 4 1 2 0 5 6 8]
#
# 49  KitchenAbvGr         int64
# [1 2 3 0]
#
# 50  KitchenQual          object
# ['Gd' 'TA' 'Ex' 'Fa']
#
# 51  TotRmsAbvGrd         int64
# [ 8  6  7  9  5 11  4 10 12  3  2 14]
#
# 52  Functional           object
# ['Typ' 'Min1' 'Maj1' 'Min2' 'Mod' 'Maj2' 'Sev']
#
# 53  Fireplaces           int64
# [0 1 2 3]
#
# 54  FireplaceQu          object
# ['None' 'TA' 'Gd' 'Fa' 'Ex' 'Po']
#
# 55  GarageType           object
# ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' 'None' 'Basment' '2Types']
#
# 56  GarageYrBlt          object
# [7.0 4.0 6.0 8.0 0.0 3.0 2.0 9.0 5.0 1.0 'None']
#
# 57  GarageFinish         object
# ['RFn' 'Unf' 'Fin' 'None']
#
# 58  GarageCars           int64
# [2 3 1 0 4]
#
# 59  GarageArea           int64
# list length: 441
#
# 60  GarageQual           object
# ['TA' 'Fa' 'Gd' 'None' 'Ex' 'Po']
#
# 61  GarageCond           object
# ['TA' 'Fa' 'None' 'Gd' 'Po' 'Ex']
#
# 62  PavedDrive           object
# ['Y' 'N' 'P']
#
# 63  WoodDeckSF           int64
# list length: 274
#
# 64  OpenPorchSF          int64
# list length: 202
#
# 65  EnclosedPorch        int64
# list length: 120
#
# 66  3SsnPorch            int64
# [  0 320 407 130 180 168 140 508 238 245 196 144 182 162  23 216  96 153
#  290 304]
#
# 67  ScreenPorch          int64
# list length: 76
#
# 68  PoolArea             int64
# [  0 512 648 576 555 480 519 738]
#
# 69  PoolQC               object
# ['None' 'Ex' 'Fa' 'Gd']
#
# 70  Fence                object
# ['None' 'MnPrv' 'GdWo' 'GdPrv' 'MnWw']
#
# 71  MiscFeature          object
# ['None' 'Shed' 'Gar2' 'Othr' 'TenC']
#
# 72  MiscVal              int64
# list length: 21
#
# 73  MoSold               int64
# [ 2  5  9 12 10  8 11  4  1  7  3  6]
#
# 74  YrSold               int64
# [2008 2007 2006 2009 2010]
#
# 75  SaleType             object
# ['WD' 'New' 'COD' 'ConLD' 'ConLI' 'CWD' 'ConLw' 'Con' 'Oth']
#
# 76  SaleCondition        object
# ['Normal' 'Abnorml' 'Partial' 'AdjLand' 'Alloca' 'Family']
#
# 77  SalePrice            int64
# list length: 663
#
# 78  MasVnrType_1         object
# ['BrkFace' 'None' 'Stone' 'BrkCmn' 'CBlock']
#
# 79  MasVnrType_2         object
# ['BrkFace' 'None' 'Stone' 'BrkCmn']
#
# 80  MasVnrArea_1         float64
# list length: 328
#
# 81  MasVnrArea_2         float64
# list length: 327

# %% [markdown]
# For consistency, we will treat all quality measures as categorical. We will also treat home features, such as number of rooms, as categorical.

# %% [markdown]
# The following features still need to be processed:
#
# These all need to be categorical:
#
#     16  OverallQual          int64      [ 7  6  8  5  9  4 10  3  1  2]
#     17  OverallCond          int64      [5 8 6 7 4 2 3 9 1]
#     44  BsmtFullBath         int64      [1 0 2 3]
#     45  BsmtHalfBath         int64      [0 1 2]
#     46  FullBath             int64      [2 1 3 0]
#     47  HalfBath             int64      [1 0 2]
#     48  BedroomAbvGr         int64      [3 4 1 2 0 5 6 8]
#     49  KitchenAbvGr         int64      [1 2 3 0]
#     51  TotRmsAbvGrd         int64      [ 8  6  7  9  5 11  4 10 12  3  2 14]
#     53  Fireplaces           int64      [0 1 2 3]
#     56  GarageYrBlt          object     [7.0 4.0 6.0 8.0 0.0 3.0 2.0 9.0 5.0 1.0 'None']
#     58  GarageCars           int64      [2 3 1 0 4]
#     73  MoSold               int64      [ 2  5  9 12 10  8 11  4  1  7  3  6]
#     74  YrSold               int64      [2008 2007 2006 2009 2010]
#
# Bin these, then make categorical:
#
#     18  YearBuilt            int64      list length: 112
#     19  YearRemodAdd         int64      list length: 61
#
# Make this a Boolean:
#
#     38  CentralAir           object     ['Y' 'N']
#
# Make two different dataframes for each:
#
#     78  MasVnrType_1         object     ['BrkFace' 'None' 'Stone' 'BrkCmn' 'CBlock']
#     79  MasVnrType_2         object     ['BrkFace' 'None' 'Stone' 'BrkCmn']
#     80  MasVnrArea_1         float64    list length: 328
#     81  MasVnrArea_2         float64    list length: 327

# %%
ames_train_df.OverallQual = ames_train_df.OverallQual.astype('str')
ames_train_df.OverallCond = ames_train_df.OverallCond.astype('str')
ames_train_df.OverallQual = ames_train_df.OverallQual.astype('str') 
ames_train_df.OverallCond = ames_train_df.OverallCond.astype('str') 
ames_train_df.BsmtFullBath = ames_train_df.BsmtFullBath.astype('str')
ames_train_df.BsmtHalfBath = ames_train_df.BsmtHalfBath.astype('str')
ames_train_df.FullBath = ames_train_df.FullBath.astype('str')    
ames_train_df.HalfBath = ames_train_df.HalfBath.astype('str')    
ames_train_df.BedroomAbvGr = ames_train_df.BedroomAbvGr.astype('str')
ames_train_df.KitchenAbvGr = ames_train_df.KitchenAbvGr.astype('str')
ames_train_df.TotRmsAbvGrd = ames_train_df.TotRmsAbvGrd.astype('str')
ames_train_df.Fireplaces = ames_train_df.Fireplaces.astype('str')  
ames_train_df.GarageYrBlt = ames_train_df.GarageYrBlt.astype('str') 
ames_train_df.GarageCars = ames_train_df.GarageCars.astype('str')  
ames_train_df.MoSold = ames_train_df.MoSold.astype('str')      
ames_train_df.YrSold = ames_train_df.YrSold.astype('str')      

ames_test_df.OverallQual = ames_test_df.OverallQual.astype('str')
ames_test_df.OverallCond = ames_test_df.OverallCond.astype('str')
ames_test_df.OverallQual = ames_test_df.OverallQual.astype('str') 
ames_test_df.OverallCond = ames_test_df.OverallCond.astype('str') 
ames_test_df.BsmtFullBath = ames_test_df.BsmtFullBath.astype('str')
ames_test_df.BsmtHalfBath = ames_test_df.BsmtHalfBath.astype('str')
ames_test_df.FullBath = ames_test_df.FullBath.astype('str')    
ames_test_df.HalfBath = ames_test_df.HalfBath.astype('str')    
ames_test_df.BedroomAbvGr = ames_test_df.BedroomAbvGr.astype('str')
ames_test_df.KitchenAbvGr = ames_test_df.KitchenAbvGr.astype('str')
ames_test_df.TotRmsAbvGrd = ames_test_df.TotRmsAbvGrd.astype('str')
ames_test_df.Fireplaces = ames_test_df.Fireplaces.astype('str')  
ames_test_df.GarageYrBlt = ames_test_df.GarageYrBlt.astype('str') 
ames_test_df.GarageCars = ames_test_df.GarageCars.astype('str')  
ames_test_df.MoSold = ames_test_df.MoSold.astype('str')      
ames_test_df.YrSold = ames_test_df.YrSold.astype('str')

# %% [markdown]
# #### Bin Years

# %%
YearBuilt = ames_train_df['YearBuilt'].values
_, deciles = pd.qcut(ames_train_df['YearBuilt'], 10, retbins=True)

# %%
YearBuilt = ames_train_df['YearBuilt'].copy()
YearBuilt[YearBuilt < deciles[1]] = 0
YearBuilt[YearBuilt >= deciles[9]] = 9
for i in range(1,9):
    YearBuilt[(YearBuilt >= deciles[i]) & (YearBuilt < deciles[i+1])] = i
ames_train_df['YearBuilt'] = YearBuilt.astype('str')

# %%
YearBuilt = ames_test_df['YearBuilt'].copy()
YearBuilt[YearBuilt < deciles[1]] = 0
YearBuilt[YearBuilt >= deciles[9]] = 9
for i in range(1,9):
    YearBuilt[(YearBuilt >= deciles[i]) & (YearBuilt < deciles[i+1])] = i
ames_test_df['YearBuilt'] = YearBuilt.astype('str')

# %%
ames_test_df['YearBuilt'].unique(), ames_train_df['YearBuilt'].unique()
# Out:
# (array(['3', '7', '6', '4', '5', '9', '8', '0', '2', '1'], dtype=object),
#  array(['8', '5', '7', '0', '6', '1', '4', '3', '9', '2'], dtype=object))

# %%
YearRemodAdd = ames_train_df['YearRemodAdd'].values
_, deciles = pd.qcut(ames_train_df['YearRemodAdd'], 5, retbins=True)

# %%
YearRemodAdd = ames_train_df['YearRemodAdd'].copy()
YearRemodAdd[YearRemodAdd < deciles[1]] = 0
YearRemodAdd[YearRemodAdd >= deciles[4]] = 4
for i in range(1,4):
    YearRemodAdd[(YearRemodAdd >= deciles[i]) & (YearRemodAdd < deciles[i+1])] = i
ames_train_df['YearRemodAdd'] = YearRemodAdd.astype('str')

# %%
YearRemodAdd = ames_test_df['YearRemodAdd'].copy()
YearRemodAdd[YearRemodAdd < deciles[1]] = 0
YearRemodAdd[YearRemodAdd >= deciles[4]] = 4
for i in range(1,4):
    YearRemodAdd[(YearRemodAdd >= deciles[i]) & (YearRemodAdd < deciles[i+1])] = i
ames_test_df['YearRemodAdd'] = YearRemodAdd.astype('str')

# %%
ames_test_df['YearRemodAdd'].unique(), ames_train_df['YearRemodAdd'].unique()
# Out:
# (array(['0', '3', '2', '4', '1'], dtype=object),
#  array(['3', '1', '2', '4', '0'], dtype=object))

# %% [markdown]
# #### Boolean Feature

# %%
ames_test_df['CentralAir'] = ames_test_df['CentralAir'].mask(ames_test_df['CentralAir'] == 'N', False)
ames_test_df['CentralAir'] = ames_test_df['CentralAir'].mask(ames_test_df['CentralAir'] == 'Y', True)

# %% [markdown]
# # Verify Features

# %%
for col in ames_train_df.columns:
    if ames_train_df[col].dtype != np.dtype('O'):
        ames_train_df[col] = ames_train_df[col].astype('float')
    if ames_train_df[col].dtype == np.dtype('O'):
        ames_train_df[col] = ames_train_df[col].astype('category')
for col in ames_test_df.columns:
    if ames_test_df[col].dtype != np.dtype('O'):
        ames_test_df[col] = ames_test_df[col].astype('float')  
    if ames_test_df[col].dtype == np.dtype('O'):
        ames_test_df[col] = ames_test_df[col].astype('category')

# %%
for i, col in enumerate(ames_train_df.columns):
    dtype = ames_train_df[col].dtype    
    unique_train = ames_train_df[col].unique()
    unique_test = ames_train_df[col].unique()
    diff_test_train = set(unique_test) - set(unique_train)
    if len(unique_train) > 20:
        unique_train = "list length: {}".format(len(unique_train))
    print("{:3} {:20} {:10} {}".format(str(i), col, str(dtype), str(unique_train)))
    print()
# Out:
# 0   MSSubClass           category   [60, 20, 70, 50, 190, ..., 80, 160, 75, 180, 40]
# Length: 15
# Categories (15, int64): [60, 20, 70, 50, ..., 160, 75, 180, 40]
#
# 1   MSZoning             category   [RL, RM, C (all), FV, RH]
# Categories (5, object): [RL, RM, C (all), FV, RH]
#
# 2   LotFrontage          float64    list length: 111
#
# 3   LotArea              float64    list length: 1072
#
# 4   Street               category   [Pave, Grvl]
# Categories (2, object): [Pave, Grvl]
#
# 5   Alley                category   [None, Grvl, Pave]
# Categories (3, object): [None, Grvl, Pave]
#
# 6   LotShape             category   [Reg, IR1, IR2, IR3]
# Categories (4, object): [Reg, IR1, IR2, IR3]
#
# 7   LandContour          category   [Lvl, Bnk, Low, HLS]
# Categories (4, object): [Lvl, Bnk, Low, HLS]
#
# 8   Utilities            category   [AllPub, NoSeWa]
# Categories (2, object): [AllPub, NoSeWa]
#
# 9   LotConfig            category   [Inside, FR2, Corner, CulDSac, FR3]
# Categories (5, object): [Inside, FR2, Corner, CulDSac, FR3]
#
# 10  LandSlope            category   [Gtl, Mod, Sev]
# Categories (3, object): [Gtl, Mod, Sev]
#
# 11  Neighborhood         category   list length: 25
#
# 12  Condition1           category   [Norm, Feedr, PosN, Artery, RRAe, RRNn, RRAn, PosA, RRNe]
# Categories (9, object): [Norm, Feedr, PosN, Artery, ..., RRNn, RRAn, PosA, RRNe]
#
# 13  Condition2           category   [Norm, Artery, RRNn, Feedr, PosN, PosA, RRAn, RRAe]
# Categories (8, object): [Norm, Artery, RRNn, Feedr, PosN, PosA, RRAn, RRAe]
#
# 14  BldgType             category   [1Fam, 2fmCon, Duplex, TwnhsE, Twnhs]
# Categories (5, object): [1Fam, 2fmCon, Duplex, TwnhsE, Twnhs]
#
# 15  HouseStyle           category   [2Story, 1Story, 1.5Fin, 1.5Unf, SFoyer, SLvl, 2.5Unf, 2.5Fin]
# Categories (8, object): [2Story, 1Story, 1.5Fin, 1.5Unf, SFoyer, SLvl, 2.5Unf, 2.5Fin]
#
# 16  OverallQual          category   [7, 6, 8, 5, 9, 4, 10, 3, 1, 2]
# Categories (10, object): [7, 6, 8, 5, ..., 10, 3, 1, 2]
#
# 17  OverallCond          category   [5, 8, 6, 7, 4, 2, 3, 9, 1]
# Categories (9, object): [5, 8, 6, 7, ..., 2, 3, 9, 1]
#
# 18  YearBuilt            category   [8, 5, 7, 0, 6, 1, 4, 3, 9, 2]
# Categories (10, object): [8, 5, 7, 0, ..., 4, 3, 9, 2]
#
# 19  YearRemodAdd         category   [3, 1, 2, 4, 0]
# Categories (5, object): [3, 1, 2, 4, 0]
#
# 20  RoofStyle            category   [Gable, Hip, Gambrel, Mansard, Flat, Shed]
# Categories (6, object): [Gable, Hip, Gambrel, Mansard, Flat, Shed]
#
# 21  RoofMatl             category   [CompShg, WdShngl, Metal, WdShake, Membran, Tar&Grv, Roll, ClyTile]
# Categories (8, object): [CompShg, WdShngl, Metal, WdShake, Membran, Tar&Grv, Roll, ClyTile]
#
# 22  Exterior1st          category   [VinylSd, MetalSd, Wd Sdng, HdBoard, BrkFace, ..., BrkComm, AsphShn, Stone, ImStucc, CBlock]
# Length: 15
# Categories (15, object): [VinylSd, MetalSd, Wd Sdng, HdBoard, ..., AsphShn, Stone, ImStucc, CBlock]
#
# 23  Exterior2nd          category   [VinylSd, MetalSd, Wd Shng, HdBoard, Plywood, ..., ImStucc, AsphShn, Stone, Other, CBlock]
# Length: 16
# Categories (16, object): [VinylSd, MetalSd, Wd Shng, HdBoard, ..., AsphShn, Stone, Other, CBlock]
#
# 24  ExterQual            category   [Gd, TA, Ex, Fa]
# Categories (4, object): [Gd, TA, Ex, Fa]
#
# 25  ExterCond            category   [TA, Gd, Fa, Po, Ex]
# Categories (5, object): [TA, Gd, Fa, Po, Ex]
#
# 26  Foundation           category   [PConc, CBlock, BrkTil, Wood, Slab, Stone]
# Categories (6, object): [PConc, CBlock, BrkTil, Wood, Slab, Stone]
#
# 27  BsmtQual             category   [Gd, TA, Ex, None, Fa]
# Categories (5, object): [Gd, TA, Ex, None, Fa]
#
# 28  BsmtCond             category   [TA, Gd, None, Fa, Po]
# Categories (5, object): [TA, Gd, None, Fa, Po]
#
# 29  BsmtExposure         category   [No, Gd, Mn, Av, None]
# Categories (5, object): [No, Gd, Mn, Av, None]
#
# 30  BsmtFinType1         category   [GLQ, ALQ, Unf, Rec, BLQ, None, LwQ]
# Categories (7, object): [GLQ, ALQ, Unf, Rec, BLQ, None, LwQ]
#
# 31  BsmtFinSF1           float64    list length: 637
#
# 32  BsmtFinType2         category   [Unf, BLQ, None, ALQ, Rec, LwQ, GLQ]
# Categories (7, object): [Unf, BLQ, None, ALQ, Rec, LwQ, GLQ]
#
# 33  BsmtFinSF2           float64    list length: 144
#
# 34  BsmtUnfSF            float64    list length: 780
#
# 35  TotalBsmtSF          float64    list length: 721
#
# 36  Heating              category   [GasA, GasW, Grav, Wall, OthW, Floor]
# Categories (6, object): [GasA, GasW, Grav, Wall, OthW, Floor]
#
# 37  HeatingQC            category   [Ex, Gd, TA, Fa, Po]
# Categories (5, object): [Ex, Gd, TA, Fa, Po]
#
# 38  CentralAir           category   [Y, N]
# Categories (2, object): [Y, N]
#
# 39  Electrical           category   [SBrkr, FuseF, FuseA, FuseP, Mix]
# Categories (5, object): [SBrkr, FuseF, FuseA, FuseP, Mix]
#
# 40  1stFlrSF             float64    list length: 752
#
# 41  2ndFlrSF             float64    list length: 417
#
# 42  LowQualFinSF         float64    list length: 24
#
# 43  GrLivArea            float64    list length: 861
#
# 44  BsmtFullBath         category   [1, 0, 2, 3]
# Categories (4, object): [1, 0, 2, 3]
#
# 45  BsmtHalfBath         category   [0, 1, 2]
# Categories (3, object): [0, 1, 2]
#
# 46  FullBath             category   [2, 1, 3, 0]
# Categories (4, object): [2, 1, 3, 0]
#
# 47  HalfBath             category   [1, 0, 2]
# Categories (3, object): [1, 0, 2]
#
# 48  BedroomAbvGr         category   [3, 4, 1, 2, 0, 5, 6, 8]
# Categories (8, object): [3, 4, 1, 2, 0, 5, 6, 8]
#
# 49  KitchenAbvGr         category   [1, 2, 3, 0]
# Categories (4, object): [1, 2, 3, 0]
#
# 50  KitchenQual          category   [Gd, TA, Ex, Fa]
# Categories (4, object): [Gd, TA, Ex, Fa]
#
# 51  TotRmsAbvGrd         category   [8, 6, 7, 9, 5, ..., 10, 12, 3, 2, 14]
# Length: 12
# Categories (12, object): [8, 6, 7, 9, ..., 12, 3, 2, 14]
#
# 52  Functional           category   [Typ, Min1, Maj1, Min2, Mod, Maj2, Sev]
# Categories (7, object): [Typ, Min1, Maj1, Min2, Mod, Maj2, Sev]
#
# 53  Fireplaces           category   [0, 1, 2, 3]
# Categories (4, object): [0, 1, 2, 3]
#
# 54  FireplaceQu          category   [None, TA, Gd, Fa, Ex, Po]
# Categories (6, object): [None, TA, Gd, Fa, Ex, Po]
#
# 55  GarageType           category   [Attchd, Detchd, BuiltIn, CarPort, None, Basment, 2Types]
# Categories (7, object): [Attchd, Detchd, BuiltIn, CarPort, None, Basment, 2Types]
#
# 56  GarageYrBlt          category   [7.0, 4.0, 6.0, 8.0, 0.0, ..., 2.0, 9.0, 5.0, 1.0, None]
# Length: 11
# Categories (11, object): [7.0, 4.0, 6.0, 8.0, ..., 9.0, 5.0, 1.0, None]
#
# 57  GarageFinish         category   [RFn, Unf, Fin, None]
# Categories (4, object): [RFn, Unf, Fin, None]
#
# 58  GarageCars           category   [2, 3, 1, 0, 4]
# Categories (5, object): [2, 3, 1, 0, 4]
#
# 59  GarageArea           float64    list length: 441
#
# 60  GarageQual           category   [TA, Fa, Gd, None, Ex, Po]
# Categories (6, object): [TA, Fa, Gd, None, Ex, Po]
#
# 61  GarageCond           category   [TA, Fa, None, Gd, Po, Ex]
# Categories (6, object): [TA, Fa, None, Gd, Po, Ex]
#
# 62  PavedDrive           category   [Y, N, P]
# Categories (3, object): [Y, N, P]
#
# 63  WoodDeckSF           float64    list length: 274
#
# 64  OpenPorchSF          float64    list length: 202
#
# 65  EnclosedPorch        float64    list length: 120
#
# 66  3SsnPorch            float64    [   0.  320.  407.  130.  180.  168.  140.  508.  238.  245.  196.  144.
#   182.  162.   23.  216.   96.  153.  290.  304.]
#
# 67  ScreenPorch          float64    list length: 76
#
# 68  PoolArea             float64    [   0.  512.  648.  576.  555.  480.  519.  738.]
#
# 69  PoolQC               category   [None, Ex, Fa, Gd]
# Categories (4, object): [None, Ex, Fa, Gd]
#
# 70  Fence                category   [None, MnPrv, GdWo, GdPrv, MnWw]
# Categories (5, object): [None, MnPrv, GdWo, GdPrv, MnWw]
#
# 71  MiscFeature          category   [None, Shed, Gar2, Othr, TenC]
# Categories (5, object): [None, Shed, Gar2, Othr, TenC]
#
# 72  MiscVal              float64    list length: 21
#
# 73  MoSold               category   [2, 5, 9, 12, 10, ..., 4, 1, 7, 3, 6]
# Length: 12
# Categories (12, object): [2, 5, 9, 12, ..., 1, 7, 3, 6]
#
# 74  YrSold               category   [2008, 2007, 2006, 2009, 2010]
# Categories (5, object): [2008, 2007, 2006, 2009, 2010]
#
# 75  SaleType             category   [WD, New, COD, ConLD, ConLI, CWD, ConLw, Con, Oth]
# Categories (9, object): [WD, New, COD, ConLD, ..., CWD, ConLw, Con, Oth]
#
# 76  SaleCondition        category   [Normal, Abnorml, Partial, AdjLand, Alloca, Family]
# Categories (6, object): [Normal, Abnorml, Partial, AdjLand, Alloca, Family]
#
# 77  SalePrice            float64    list length: 663
#
# 78  MasVnrType_1         category   [BrkFace, None, Stone, BrkCmn, CBlock]
# Categories (5, object): [BrkFace, None, Stone, BrkCmn, CBlock]
#
# 79  MasVnrType_2         category   [BrkFace, None, Stone, BrkCmn]
# Categories (4, object): [BrkFace, None, Stone, BrkCmn]
#
# 80  MasVnrArea_1         float64    list length: 328
#
# 81  MasVnrArea_2         float64    list length: 327

# %% [markdown]
# #### Split DataFrames

# %%
ames_train_cblock_df = (ames_train_df.drop('MasVnrType_2', axis=1)
                                     .drop('MasVnrArea_2', axis=1))
ames_test_cblock_df = (ames_test_df.drop('MasVnrType_2', axis=1)
                                   .drop('MasVnrArea_2', axis=1))

# %%
ames_train_none_df = (ames_train_df.drop('MasVnrType_1', axis=1)
                                   .drop('MasVnrArea_1', axis=1))
ames_test_none_df = (ames_test_df.drop('MasVnrType_1', axis=1)
                                 .drop('MasVnrArea_1', axis=1))

# %%
ames_train_cblock_df.to_pickle('data/train_cblock_df.p')
ames_test_cblock_df.to_pickle('data/test_cblock_df.p')
ames_train_none_df.to_pickle('data/train_none_df.p')
ames_test_none_df.to_pickle('data/test_none_df.p')
